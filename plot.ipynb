# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf

# 创建与图片完全一致的示例数据
data = {
    'Date': pd.date_range(start='2021-01-01', periods=50, freq='D'),
    'Open': [100, 98, 95, 92, 95, 97, 96, 94, 93, 90, 88, 89, 91, 90, 88, 89, 87, 85, 83, 82, 84, 86, 85, 84, 82, 81, 80, 78, 76, 74, 72, 70, 72, 74, 76, 78, 80, 82, 84, 83, 85, 87, 89, 91, 93, 95, 94, 96, 98, 100],
    'High': [102, 100, 97, 94, 97, 99, 98, 96, 95, 92, 90, 91, 93, 92, 90, 91, 89, 87, 85, 84, 86, 88, 87, 86, 84, 83, 82, 80, 78, 76, 74, 72, 74, 76, 78, 80, 82, 84, 86, 85, 87, 89, 91, 93, 95, 97, 96, 98, 100, 102],
    'Low': [98, 96, 93, 90, 93, 95, 94, 92, 91, 88, 86, 87, 89, 88, 86, 87, 85, 83, 81, 80, 82, 84, 83, 82, 80, 79, 78, 76, 74, 72, 70, 68, 70, 72, 74, 76, 78, 80, 82, 81, 83, 85, 87, 89, 91, 93, 92, 94, 96, 98],
    'Close': [98, 95, 92, 95, 97, 96, 94, 93, 90, 88, 89, 91, 90, 88, 89, 87, 85, 83, 82, 84, 86, 85, 84, 82, 81, 80, 78, 76, 74, 72, 70, 72, 74, 76, 78, 80, 82, 84, 83, 85, 87, 89, 91, 93, 95, 94, 96, 98, 100, 102],
    'Volume': [1000] * 50
}

df = pd.DataFrame(data)
df.set_index('Date', inplace=True)

# 定义绘图风格
mc = mpf.make_marketcolors(up='green', down='red', inherit=True)
s = mpf.make_mpf_style(marketcolors=mc, gridstyle=':', gridcolor='gray')

# 创建图表
fig, ax = mpf.plot(df, type='candle', style=s, title='DOUBLE BOTTOM', ylabel='Price', returnfig=True)

# 添加注释和标记
ax[0].annotate('Previous Downtrend', xy=(0.1, 0.8), xycoords='axes fraction', color='red', fontsize=12)
ax[0].annotate('First Bottom', xy=(pd.Timestamp('2021-01-10'), 88), xytext=(pd.Timestamp('2021-01-05'), 85),
               arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12)
ax[0].annotate('Second Bottom', xy=(pd.Timestamp('2021-01-20'), 81), xytext=(pd.Timestamp('2021-01-15'), 78),
               arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12)
ax[0].annotate('Neckline with 2 rejections', xy=(pd.Timestamp('2021-01-15'), 94), xytext=(pd.Timestamp('2021-01-10'), 96),
               arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12)
ax[0].annotate('Possible Buy Entry with Breakout', xy=(pd.Timestamp('2021-01-30'), 87), xytext=(pd.Timestamp('2021-01-25'), 90),
               arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12)
ax[0].annotate('Min. Target', xy=(pd.Timestamp('2021-01-30'), 97), xytext=(pd.Timestamp('2021-01-25'), 100),
               arrowprops=dict(facecolor='black', shrink=0.05), fontsize=12)

# 显示图表
plt.show()
